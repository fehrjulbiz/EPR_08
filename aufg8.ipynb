# %%
from random import random, seed

seed(1)
hunting_success = 0.7
results = []
for i in range(12):
    results.append(random() < hunting_success)

print(f"{results.count(True) / len(results):.2f}")
# Out:
# 0.67

# %%
class Parent:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        self.energie = 1

    def display_name(self):
        print(f"My name is {self.name} and i am {self.age} years old")

    def die(self):
        del self


class Daughter(Parent):
    def __init__(self, name, age):
        super().__init__(name, age)
        self.energie = 2

    def display_energie(self):
        print(self.energie)


d1 = Daughter("Ella", 5)
d1.display_energie()
d1.die()

d1.die2()
d1.display_name()
# Out:
# 2
# My name is Ella and i am 5 years old
